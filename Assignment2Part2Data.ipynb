# %%
import pandas as pd

crime2003 = pd.read_csv('SFPD_Incidents_-_from_1_January_2003.csv')

# %%
# Get Prostitution Crimes Only
prostitution2003 = crime2003[crime2003['Category'] == "PROSTITUTION"]

# %%
#Get Lat and Lon Values
prostitutionStep = prostitution2003[["X","Y"]]
#Remove Outliers
prostitution = prostitutionStep[(prostitutionStep['Y'] < 50)]

# %%
# Rename Columns
prostitution.columns = ['lon', 'lat']

# %%
import numpy as np
from sklearn.cluster import KMeans

### For the purposes of this example, we store feature data from our
### dataframe `df`, in the `f1` and `f2` arrays. We combine this into
### a feature matrix `X` before entering it into the algorithm.
f1 = prostitution['lat'].values
f2 = prostitution['lon'].values

X=np.matrix(zip(f1,f2))
numK = range(1,7)
results = []

for i in numK:
        results.append(KMeans(n_clusters=i).fit(X))

# %%
#Create new columns and assign data
prostitution["cc"] = results[0].labels_ # Array of 0's
prostitution["k2"] = results[1].labels_
prostitution["k3"] = results[2].labels_
prostitution["k4"] = results[3].labels_
prostitution["k5"] = results[4].labels_
prostitution["k6"] = results[5].labels_
# Out:
# C:\Users\David\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\David\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\David\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\David\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\David\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\David\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#('lon', 'lat', 'k2','k3','k4','k5','k6','CC')

for i in range(1,6):
    for j, cluster in enumerate(results[i].cluster_centers_) :
        rowAdd = [cluster[1],cluster[0],1,0,0,0,0,0]
        rowAdd[i+2] = j;
        rowAdd[2] = i+1;
        prostitution.loc[len(prostitution)] = rowAdd
# Out:
# C:\Users\David\Anaconda2\lib\site-packages\ipykernel\__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
prostitution
# Out:
#                 lon        lat   cc   k2   k3   k4   k5   k6
# 3639    -122.466205  37.772541  0.0  1.0  2.0  3.0  3.0  4.0
# 5422    -122.403405  37.775421  0.0  0.0  0.0  0.0  4.0  3.0
# 6862    -122.409661  37.786439  0.0  0.0  0.0  0.0  4.0  3.0
# 7560    -122.417956  37.757880  0.0  1.0  1.0  2.0  1.0  0.0
# 8692    -122.410700  37.786988  0.0  0.0  0.0  0.0  4.0  3.0
# 8726    -122.410700  37.786988  0.0  0.0  0.0  0.0  4.0  3.0
# 8736    -122.410700  37.786988  0.0  0.0  0.0  0.0  4.0  3.0
# 8781    -122.417818  37.757888  0.0  1.0  1.0  2.0  1.0  0.0
# 8939    -122.388380  37.783310  0.0  0.0  0.0  0.0  4.0  3.0
# 8940    -122.388380  37.783310  0.0  0.0  0.0  0.0  4.0  3.0
# 8986    -122.388380  37.783310  0.0  0.0  0.0  0.0  4.0  3.0
# 8987    -122.388380  37.783310  0.0  0.0  0.0  0.0  4.0  3.0
# 9011    -122.388380  37.783310  0.0  0.0  0.0  0.0  4.0  3.0
# 9012    -122.388380  37.783310  0.0  0.0  0.0  0.0  4.0  3.0
# 9077    -122.403405  37.775421  0.0  0.0  0.0  0.0  4.0  3.0
# 9078    -122.403405  37.775421  0.0  0.0  0.0  0.0  4.0  3.0
# 9104    -122.388380  37.783310  0.0  0.0  0.0  0.0  4.0  3.0
# 9105    -122.388380  37.783310  0.0  0.0  0.0  0.0  4.0  3.0
# 9125    -122.388380  37.783310  0.0  0.0  0.0  0.0  4.0  3.0
# 9126    -122.388380  37.783310  0.0  0.0  0.0  0.0  4.0  3.0
#